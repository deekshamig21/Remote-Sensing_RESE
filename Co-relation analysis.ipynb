# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr

# Input data
data = {
    "Year": [1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "VHI": [48.95, 58.13, 55.32, 33.42, 38.12, 39.05, 43.55, 43.17, 42.08, 41.68, 59.45, 52.37, 69.90, 49.27, 38.57, 54.28, 55.21, 48.09, 34.69, 29.80, 28.22, 41.60, 37.02, 53.41, 40.23, 53.64, 46.24, 48.39, 45.37, 50.90, 47.13, 48.80, 41.61, 42.59, 37.16, 39.01, 32.92, 54.48, 57.24, 41.58, 45.30, 57.61],
    "SMT": [301.30, 300.60, 301.42, 307.30, 303.94, 304.44, 301.40, 304.37, 304.48, 304.38, 302.05, 303.72, 298.13, 304.98, 305.16, 302.39, 304.02, 304.23, 303.28, 305.40, 306.57, 303.30, 303.21, 303.26, 304.28, 304.35, 304.98, 304.86, 304.69, 303.90, 304.25, 303.14, 304.13, 303.93, 304.86, 304.51, 305.41, 302.00, 302.57, 304.31, 304.23, 302.42],
    "TCI": [68.16, 73.23, 68.04, 31.59, 45.20, 43.60, 56.21, 41.64, 42.10, 44.46, 60.08, 48.60, 80.47, 42.93, 35.61, 62.14, 47.20, 45.19, 51.14, 27.83, 23.82, 46.58, 39.62, 51.39, 39.13, 42.30, 36.63, 38.49, 34.63, 44.69, 42.80, 48.80, 41.47, 42.76, 32.67, 36.98, 30.19, 60.42, 54.67, 39.07, 42.54, 55.42],
    "VCI": [29.75, 43.03, 42.60, 35.26, 31.03, 34.50, 30.90, 44.70, 42.06, 38.91, 58.81, 56.14, 59.34, 55.61, 41.52, 46.42, 63.22, 51.00, 18.24, 31.77, 32.62, 36.62, 34.41, 55.43, 41.32, 64.97, 55.84, 58.30, 56.10, 57.12, 51.45, 48.76, 41.66, 42.31, 41.62, 41.00, 35.65, 48.34, 59.60, 44.05, 48.10, 59.66]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Calculate correlation coefficients
correlation_matrix = df[["VHI", "SMT", "TCI", "VCI"]].corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Perform pairwise Pearson correlation analysis
print("\nPairwise Pearson Correlation Coefficients:")
variables = ["VHI", "SMT", "TCI", "VCI"]
for i in range(len(variables)):
    for j in range(i + 1, len(variables)):
        var1 = variables[i]
        var2 = variables[j]
        r, p_value = pearsonr(df[var1], df[var2])
        print(f"{var1} & {var2}: r = {r:.2f}, p-value = {p_value:.4f}")
# Out:
# Correlation Matrix:
#           VHI       SMT       TCI       VCI
# VHI  1.000000 -0.740952  0.799909  0.740077
# SMT -0.740952  1.000000 -0.944259 -0.154179
# TCI  0.799909 -0.944259  1.000000  0.188409
# VCI  0.740077 -0.154179  0.188409  1.000000
#
# Pairwise Pearson Correlation Coefficients:
# VHI & SMT: r = -0.74, p-value = 0.0000
# VHI & TCI: r = 0.80, p-value = 0.0000
# VHI & VCI: r = 0.74, p-value = 0.0000
# SMT & TCI: r = -0.94, p-value = 0.0000
# SMT & VCI: r = -0.15, p-value = 0.3296
# TCI & VCI: r = 0.19, p-value = 0.2321

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Input data
data = {
    "Year": [1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "VHI": [48.95, 58.13, 55.32, 33.42, 38.12, 39.05, 43.55, 43.17, 42.08, 41.68, 59.45, 52.37, 69.90, 49.27, 38.57, 54.28, 55.21, 48.09, 34.69, 29.80, 28.22, 41.60, 37.02, 53.41, 40.23, 53.64, 46.24, 48.39, 45.37, 50.90, 47.13, 48.80, 41.61, 42.59, 37.16, 39.01, 32.92, 54.48, 57.24, 41.58, 45.30, 57.61],
    "SMT": [301.30, 300.60, 301.42, 307.30, 303.94, 304.44, 301.40, 304.37, 304.48, 304.38, 302.05, 303.72, 298.13, 304.98, 305.16, 302.39, 304.02, 304.23, 303.28, 305.40, 306.57, 303.30, 303.21, 303.26, 304.28, 304.35, 304.98, 304.86, 304.69, 303.90, 304.25, 303.14, 304.13, 303.93, 304.86, 304.51, 305.41, 302.00, 302.57, 304.31, 304.23, 302.42],
    "TCI": [68.16, 73.23, 68.04, 31.59, 45.20, 43.60, 56.21, 41.64, 42.10, 44.46, 60.08, 48.60, 80.47, 42.93, 35.61, 62.14, 47.20, 45.19, 51.14, 27.83, 23.82, 46.58, 39.62, 51.39, 39.13, 42.30, 36.63, 38.49, 34.63, 44.69, 42.80, 48.80, 41.47, 42.76, 32.67, 36.98, 30.19, 60.42, 54.67, 39.07, 42.54, 55.42],
    "VCI": [29.75, 43.03, 42.60, 35.26, 31.03, 34.50, 30.90, 44.70, 42.06, 38.91, 58.81, 56.14, 59.34, 55.61, 41.52, 46.42, 63.22, 51.00, 18.24, 31.77, 32.62, 36.62, 34.41, 55.43, 41.32, 64.97, 55.84, 58.30, 56.10, 57.12, 51.45, 48.76, 41.66, 42.31, 41.62, 41.00, 35.65, 48.34, 59.60, 44.05, 48.10, 59.66]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Set up the figure and axes
plt.figure(figsize=(15, 10))

# Scatter plot for VHI vs SMT
plt.subplot(2, 2, 1)
sns.scatterplot(x=df["VHI"], y=df["SMT"], color="blue")
plt.title("VHI vs SMT")
plt.xlabel("VHI")
plt.ylabel("SMT")

# Scatter plot for VHI vs TCI
plt.subplot(2, 2, 2)
sns.scatterplot(x=df["VHI"], y=df["TCI"], color="green")
plt.title("VHI vs TCI")
plt.xlabel("VHI")
plt.ylabel("TCI")

# Scatter plot for VHI vs VCI
plt.subplot(2, 2, 3)
sns.scatterplot(x=df["VHI"], y=df["VCI"], color="red")
plt.title("VHI vs VCI")
plt.xlabel("VHI")
plt.ylabel("VCI")

# Scatter plot for TCI vs VCI
plt.subplot(2, 2, 4)
sns.scatterplot(x=df["TCI"], y=df["VCI"], color="purple")
plt.title("TCI vs VCI")
plt.xlabel("TCI")
plt.ylabel("VCI")

# Adjust layout and display plots
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr

# Input data for VHI
vhi_data = {
    "Year": [1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "VHI": [48.95, 58.13, 55.32, 33.42, 38.12, 39.05, 43.55, 43.17, 42.08, 41.68, 59.45, 52.37, 69.90, 49.27, 38.57, 54.28, 55.21, 48.09, 34.69, 29.80, 28.22, 41.60, 37.02, 53.41, 40.23, 53.64, 46.24, 48.39, 45.37, 50.90, 47.13, 48.80, 41.61, 42.59, 37.16, 39.01, 32.92, 54.48, 57.24, 41.58, 45.30, 57.61]
}

# Input data for ET (Evapotranspiration)
et_data = {
    "Year": [1995, 1996, 1997, 1998, 1999, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "ET": [2.492785, 3.1827443, 3.5625532, 3.9807267, 4.018859, 2.714773, 3.2028267, 5.637308, 4.2302265, 3.3569744, 4.891741, 4.14484, 2.9853764, 4.348382, 6.0549893, 3.4098914, 2.423936, 3.0646164, 3.3337975, 3.435198, 4.019501, 8.398167, 7.269271, 4.2766256, 3.716907, 2.716515, 4.052356, 3.6593556]
}

# Input data for GRACE (Water Equivalent Thickness – Land)
grace_data = {
    "Year": [2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "GRACE": [12.11, 13.23, 6.14, 14.45, 7.08, 9.00, 3.31, 0.32, 5.88, 4.86, 3.14, 3.03, 1.03, 4.54, 0.68, -5.52, -10.20, -11.83, -6.21, -14.89, -18.47, -15.85]
}

# Create DataFrames
df_vhi = pd.DataFrame(vhi_data)
df_et = pd.DataFrame(et_data)
df_grace = pd.DataFrame(grace_data)

# Merge datasets on the "Year" column
df = pd.merge(df_vhi, df_et, on="Year", how="inner")
df = pd.merge(df, df_grace, on="Year", how="inner")

# Display the merged DataFrame
print("Merged DataFrame:")
print(df)

# Calculate correlation coefficients
correlation_matrix = df[["VHI", "ET", "GRACE"]].corr()

# Print the correlation matrix
print("\nCorrelation Matrix:")
print(correlation_matrix)

# Perform pairwise Pearson correlation analysis
print("\nPairwise Pearson Correlation Coefficients:")
variables = ["VHI", "ET", "GRACE"]
for i in range(len(variables)):
    for j in range(i + 1, len(variables)):
        var1 = variables[i]
        var2 = variables[j]
        r, p_value = pearsonr(df[var1], df[var2])
        print(f"{var1} & {var2}: r = {r:.2f}, p-value = {p_value:.4f}")
# Out:
# Merged DataFrame:
#     Year    VHI        ET  GRACE
# 0   2002  28.22  3.202827  12.11
# 1   2003  41.60  5.637308  13.23
# 2   2004  37.02  4.230226   6.14
# 3   2005  53.41  3.356974  14.45
# 4   2006  40.23  4.891741   7.08
# 5   2007  53.64  4.144840   9.00
# 6   2008  46.24  2.985376   3.31
# 7   2009  48.39  4.348382   0.32
# 8   2010  45.37  6.054989   5.88
# 9   2011  50.90  3.409891   4.86
# 10  2012  47.13  2.423936   3.14
# 11  2013  48.80  3.064616   3.03
# 12  2014  41.61  3.333798   1.03
# 13  2015  42.59  3.435198   4.54
# 14  2016  37.16  4.019501   0.68
# 15  2017  39.01  8.398167  -5.52
# 16  2018  32.92  7.269271 -10.20
# 17  2019  54.48  4.276626 -11.83
# 18  2020  57.24  3.716907  -6.21
# 19  2021  41.58  2.716515 -14.89
# 20  2022  45.30  4.052356 -18.47
# 21  2023  57.61  3.659356 -15.85
#
# Correlation Matrix:
#             VHI        ET     GRACE
# VHI    1.000000 -0.314577 -0.181452
# ET    -0.314577  1.000000 -0.101611
# GRACE -0.181452 -0.101611  1.000000
#
# Pairwise Pearson Correlation Coefficients:
# VHI & ET: r = -0.31, p-value = 0.1539
# VHI & GRACE: r = -0.18, p-value = 0.4190
# ET & GRACE: r = -0.10, p-value = 0.6527

# %%
# Set up the figure and axes
plt.figure(figsize=(15, 10))

# Scatter plot for VHI vs ET
plt.subplot(2, 2, 1)
sns.scatterplot(x=df["VHI"], y=df["ET"], color="blue")
plt.title("VHI vs ET")
plt.xlabel("VHI")
plt.ylabel("ET")

# Scatter plot for VHI vs GRACE
plt.subplot(2, 2, 2)
sns.scatterplot(x=df["VHI"], y=df["GRACE"], color="green")
plt.title("VHI vs GRACE")
plt.xlabel("VHI")
plt.ylabel("GRACE")

# Scatter plot for ET vs GRACE
plt.subplot(2, 2, 3)
sns.scatterplot(x=df["ET"], y=df["GRACE"], color="red")
plt.title("ET vs GRACE")
plt.xlabel("ET")
plt.ylabel("GRACE")



# Adjust layout and display plots
plt.tight_layout()
plt.show()
